# %%
#对数据集中的3个csv文件进行聚合，生成一个csv，包含电影的信息，其中每部电影一行，信息包括电影名称、主演、平均分、所有tag
import pandas as pd

# %%
ratings = pd.read_csv('D:/zybank/ml-latest-small/ratings.csv',index_col=None)
tags=pd.read_csv('D:/zybank/ml-latest-small/tags.csv',index_col=None)
movies=pd.read_csv('D:/zybank/ml-latest-small/movies.csv',index_col=None)
links=pd.read_csv('D:/zybank/ml-latest-small/links.csv',index_col=None)

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
movies['mean_ratimg'] = ratings.groupby('movieId')['rating'].transform('mean')
movies
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# 5           6                                        Heat (1995)
# 6           7                                     Sabrina (1995)
# 7           8                                Tom and Huck (1995)
# 8           9                                Sudden Death (1995)
# 9          10                                   GoldenEye (1995)
# 10         11                     American President, The (1995)
# 11         12                 Dracula: Dead and Loving It (1995)
# 12         13                                       Balto (1995)
# ...

# %%
result = pd.merge(movies, tags, on = 'movieId', how = 'left')
result
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            1                                   Toy Story (1995)
# 2            1                                   Toy Story (1995)
# 3            2                                     Jumanji (1995)
# 4            2                                     Jumanji (1995)
# 5            2                                     Jumanji (1995)
# 6            2                                     Jumanji (1995)
# 7            3                            Grumpier Old Men (1995)
# 8            3                            Grumpier Old Men (1995)
# 9            4                           Waiting to Exhale (1995)
# 10           5                 Father of the Bride Part II (1995)
# 11           5                 Father of the Bride Part II (1995)
# 12           6                                        Heat (1995)
# ...
